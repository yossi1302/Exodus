# %%
time_slots = ["08:30", "11:00", "13:30", "16:00"]
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
        
# Data structures
courses = {}
lecturers = {}
programs = {}
classrooms = {}
        
# Schedule output
schedule = {}
