# %%
import json
from datetime import datetime, timedelta
from typing import Dict, List, Set, Tuple
from collections import defaultdict

# %%
time_slots = ["08:30", "11:00", "13:30", "16:00"]
days = ["Monday", "Tuesday", "Wednesday", "Thursday", "Friday"]
        
# Data structures
courses = {}
lecturers = {}
programs = {}
classrooms = {}
        
# Schedule output
schedule = {}

# %%
  def load_data(self, courses_file, lecturers_file, programs_file, 
                  period_file, classrooms_file):
        """Load all JSON input files"""
        
        with open(courses_file, 'r') as f:
            courses = json.load(f)
        
        with open(lecturers_file, 'r') as f:
            lecturers = json.load(f)
        
        with open(programs_file, 'r') as f:
            programs = json.load(f)
        
        with open(period_file, 'r') as f:
            period = json.load(f)
        
        with open(classrooms_file, 'r') as f:
            classrooms = json.load(f)
